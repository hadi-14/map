# %%
import matplotlib.pyplot as plt

import cartopy.crs as ccrs


def main():
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.Robinson())

    # make the map global rather than have it zoom in to
    # the extents of any plotted data
    ax.set_global()

    ax.stock_img()
    ax.coastlines()

    ax.plot(-0.08, 51.53, 'o', transform=ccrs.PlateCarree())
    ax.plot([-0.08, 132], [51.53, 43.17], transform=ccrs.PlateCarree())
    ax.plot([-0.08, 132], [51.53, 43.17], transform=ccrs.Geodetic())

    plt.show()


if __name__ == '__main__':
    main()
# Out:
# C:\Users\Hadi-PC\anaconda3\lib\site-packages\cartopy\crs.py:245: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# C:\Users\Hadi-PC\anaconda3\lib\site-packages\cartopy\crs.py:297: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# C:\Users\Hadi-PC\anaconda3\lib\site-packages\cartopy\crs.py:364: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:
# ...

# %%
from arcgis.gis import GIS
from arcgis.mapping import WebMap
gis = GIS()

# %%
gis.url
# Out:
# 'https://www.arcgis.com'

# %%
import folium

# %%
map = folium.Map(location=[29.373042, 47.975505], zoom_start=10)

# %%
map.save("index.html")

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# !pip install pytopo
# Out:
# ...
#   Using cached pytopo-1.7-py3-none-any.whl (85 kB)
# ...
#   Using cached pycairo-1.23.0-cp39-cp39-win_amd64.whl (1.2 MB)
# ...
#   Using cached simplejson-3.18.0-cp39-cp39-win_amd64.whl (76 kB)
# ...
#   Using cached requests_futures-1.0.0-py2.py3-none-any.whl (7.4 kB)
# ...
#   Using cached PyGObject-3.42.2.tar.gz (719 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build PyGObject
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [47 lines of output]
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-39
#   creating build\lib.win-amd64-cpython-39\pygtkcompat
# ...

# %%
import pytopo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 import pytopo
#
# File ~\anaconda3\lib\site-packages\pytopo\__init__.py:20
#      17 import os, sys; sys.path.append(os.path.dirname(os.path.realpath(__file__)))
#      19 from .MapCollection import MapCollection
# ---> 20 from .GenericMapCollection import GenericMapCollection
#      21 from .TopoMapCollection import TopoMapCollection
#      22 from .TopoMapCollection import Topo1MapCollection
#
# File ~\anaconda3\lib\site-packages\pytopo\GenericMapCollection.py:14
#      12 import os
#      13 from pytopo.MapUtils import MapUtils
# ---> 14 from pytopo.MapWindow import MapWindow
#      15 from pytopo.TiledMapCollection import TiledMapCollection
#      18 class GenericMapCollection(TiledMapCollection):
#
# File ~\anaconda3\lib\site-packages\pytopo\MapWindow.py:10
# ...

# %%
import osmnx as ox

# %%
road = ox.graph_from_place("kuwait")#,network_type="drive")
road

# %%
prj_road = ox.project_graph(road)

# %%
prj_road

# %%
ox.save_graph_shapefile(prj_road,filepath="map")
# Out:
# C:\Users\Hadi-PC\AppData\Roaming\Python\Python39\site-packages\osmnx\io.py:107: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf_nodes.to_file(filepath_nodes, driver="ESRI Shapefile", index=True, encoding=encoding)

# %%
ox.graph. #road
# Out:
# <module 'osmnx.graph' from 'C:\\Users\\Hadi-PC\\AppData\\Roaming\\Python\\Python39\\site-packages\\osmnx\\graph.py'>

# %%
ox.utils_graph.get_undirected(road)
